# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# NLP From Scratch: Translation with a Sequence to Sequence Network and Attention
# ===============================================================================
#
# **Author**: [Sean Robertson](https://github.com/spro)
#
# This is the third and final tutorial on doing \"NLP From Scratch\",
# where we write our own classes and functions to preprocess the data to
# do our NLP modeling tasks. We hope after you complete this tutorial that
# you\'ll proceed to learn how [torchtext]{.title-ref} can handle much of
# this preprocessing for you in the three tutorials immediately following
# this one.
#
# In this project we will be teaching a neural network to translate from
# French to English.
#
# ``` {.sourceCode .sh}
# [KEY: > input, = target, < output]
#
# > il est en train de peindre un tableau .
# = he is painting a picture .
# < he is painting a picture .
#
# > pourquoi ne pas essayer ce vin delicieux ?
# = why not try that delicious wine ?
# < why not try that delicious wine ?
#
# > elle n est pas poete mais romanciere .
# = she is not a poet but a novelist .
# < she not not a poet but a novelist .
#
# > vous etes trop maigre .
# = you re too skinny .
# < you re all alone .
# ```
#
# \... to varying degrees of success.
#
# This is made possible by the simple but powerful idea of the [sequence
# to sequence network](https://arxiv.org/abs/1409.3215), in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/seq2seq.png)
#
# To improve upon this model we\'ll use an [attention
# mechanism](https://arxiv.org/abs/1409.0473), which lets the decoder
# learn to focus over a specific range of the input sequence.
#
# **Recommended Reading:**
#
# I assume you have at least installed PyTorch, know Python, and
# understand Tensors:
#
# -   <https://pytorch.org/> For installation instructions
# -   `/beginner/deep_learning_60min_blitz`{.interpreted-text role="doc"}
#     to get started with PyTorch in general
# -   `/beginner/pytorch_with_examples`{.interpreted-text role="doc"} for
#     a wide and deep overview
# -   `/beginner/former_torchies_tutorial`{.interpreted-text role="doc"}
#     if you are former Lua Torch user
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -   [Learning Phrase Representations using RNN Encoder-Decoder for
#     Statistical Machine Translation](https://arxiv.org/abs/1406.1078)
# -   [Sequence to Sequence Learning with Neural
#     Networks](https://arxiv.org/abs/1409.3215)
# -   [Neural Machine Translation by Jointly Learning to Align and
#     Translate](https://arxiv.org/abs/1409.0473)
# -   [A Neural Conversational Model](https://arxiv.org/abs/1506.05869)
#
# You will also find the previous tutorials on
# `/intermediate/char_rnn_classification_tutorial`{.interpreted-text
# role="doc"} and
# `/intermediate/char_rnn_generation_tutorial`{.interpreted-text
# role="doc"} helpful as those concepts are very similar to the Encoder
# and Decoder models, respectively.
#
# **Requirements**

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.utils.data import TensorDataset, DataLoader, RandomSampler

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# French translation pairs.
#
# [This question on Open Data Stack
# Exchange](https://opendata.stackexchange.com/questions/3888/dataset-of-sentences-translated-into-many-languages)
# pointed me to the open translation site <https://tatoeba.org/> which has
# downloads available at <https://tatoeba.org/eng/downloads> - and better
# yet, someone did the extra work of splitting language pairs into
# individual text files here: <https://www.manythings.org/anki/>
#
# The English to French pairs are too big to include in the repository, so
# download to `data/eng-fra.txt` before continuing. The file is a tab
# separated list of translation pairs:
#
# ``` {.sourceCode .sh}
# I am cold.    J'ai froid.
# ```
#
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
# <p>Download the data from<a href="https://download.pytorch.org/tutorial/data.zip">here</a>and extract it to the current directory.</p>
# </div>

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/word-encoding.png)

# %% [markdown]
# We\'ll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called `Lang` which has word → index (`word2index`) and index → word
# (`index2word`) dictionaries, as well as a count of each word
# `word2count` which will be used to replace rare words later.

# %%
# These represent the start of a sentence (SOS) and end of a sentence (EOS), with predefined values of 0 and 1 respectively.
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)
    
    # Adds a word to word2index and index2word if it doesn't already exist, or increments its count in word2count if it has been encountered before.
    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# The files are all in Unicode, to simplify we will turn Unicode
# characters to ASCII, make everything lowercase, and trim most
# punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z!?]+", r" ", s)
    return s.strip()

# %% [markdown]
# To read the data file we will split the file into lines, and then split
# lines into pairs. The files are all English → Other Language, so if we
# want to translate from Other Language → English I added the `reverse`
# flag to reverse the pairs.

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('data/%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we\'ll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we\'re filtering to sentences that translate to
# the form \"I am\" or \"He is\" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 10

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s ",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)

# words are in reverse order. French first then English
# that's why p[1] is checked for english prefixes
def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[1].startswith(eng_prefixes)

# Filter pairs using the filterPair function
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -   Read text file and split into lines, split lines into pairs
# -   Normalize text, filter by length and content
# -   Make word lists from sentences in pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 11445 sentence pairs
# Counting words...
# Counted words:
# fra 4601
# eng 2991
# ['il est mouille', 'he s wet']

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A [Sequence to Sequence network](https://arxiv.org/abs/1409.3215), or
# seq2seq network, or [Encoder Decoder
# network](https://arxiv.org/pdf/1406.1078v3.pdf), is a model consisting
# of two RNNs called the encoder and decoder. The encoder reads an input
# sequence and outputs a single vector, and the decoder reads that vector
# to produce an output sequence.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/seq2seq.png)
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence `Je ne suis pas le chat noir` →
# `I am not the black cat`. Most of the words in the input sentence have a
# direct translation in the output sentence, but are in slightly different
# orders, e.g. `chat noir` and `black cat`. Because of the `ne/pas`
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the \"meaning\" of the input sequence into a single
# vector --- a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# ===========
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/encoder-network.png)

# %%
class EncoderRNN(nn.Module):
    # The size of the input vocabulary, i.e., the number of unique words or tokens.
    # The size of the hidden state vector, which is the internal state of the RNN that gets updated over time as the model processes the sequence.
    
    # hidden_size = 128
    # encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)

    def __init__(self, input_vocabulary_size, hidden_size, dropout_p=0.1):
        # super().__init__() This is the simpler and more modern syntax introduced in Python 3. It works in most cases and is more concise. It implicitly refers to the immediate parent class of the current class (in this case, nn.Module).
        # This is the older, more explicit form that was commonly used in Python 2 and early versions of Python 3. In this syntax, you explicitly pass the current class (EncoderRNN) and the instance of the current class (self) as arguments to super().
        super(EncoderRNN, self).__init__()


        self.hidden_size = hidden_size

        #  The input_vocabulary_size represents the size of the input vocabulary, and hidden_size represents the size of each embedding vector (the dimensionality of the word representation).
        self.embedding = nn.Embedding(input_vocabulary_size, hidden_size)
        
        # First hidden_size (input_vocabulary_size): This refers to the dimensionality of the input features at each time step in the sequence. The GRU expects input vectors at each time step to have this size. In your case, the input to the GRU is coming from an embedding layer, which has already transformed word indices into dense vectors of size hidden_size.
        # Second hidden_size (hidden_size): This represents the dimensionality of the GRU's internal hidden state. The hidden state is what the GRU updates and maintains across time steps as it processes the sequence. The hidden state vector at each time step captures the "memory" of what the GRU has seen so far in the sequence. The hidden state is also the output of the GRU at each time step
        # batch_first=True: This tells the GRU that the first dimension of the input tensor corresponds to the batch size (i.e., the input should have shape [batch_size, sequence_length, hidden_size]).
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)

        
        # During training, dropout randomly sets a fraction of the output units (neurons) in a neural network to zero at each forward pass.
        # This is specified by a parameter p, which in your case is 0.1, meaning 10% of the neurons will be randomly dropped out.
        # This forces the remaining units to learn a more robust and generalized representation of the data.
        # During the test phase (or inference), dropout is disabled, and all neurons are active.
        # With dropout, the network can't rely on any specific neurons, as they might be dropped during any iteration. As a result, the model learns to distribute the information across many neurons, reducing overfitting and improving generalization to new data.
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        # The input (which is a sequence of token indices) is first passed through the embedding layer, converting the indices into dense vectors of size hidden_size. Then, dropout is applied to the embedded vectors to randomly zero out some dimensions for regularization during training.
        embedded = self.dropout(self.embedding(input))
        # output: The output from the GRU for each time step (i.e., for each word in the sequence). It has a shape of [batch_size, sequence_length, hidden_size].
        # hidden: The hidden state after the final time step of the GRU for the last word in the sequence. This hidden state can be used to initialize the hidden state of a decoder in a sequence-to-sequence model.
        output, hidden = self.gru(embedded)
        return output, hidden

# %% [markdown]
# The Decoder
# ===========
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Simple Decoder
# ==============
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string `<SOS>`
# token, and the first hidden state is the context vector (the encoder\'s
# last hidden state).
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/decoder-network.png)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_vocabulary_size):
        super(DecoderRNN, self).__init__()
        # Maps each token in the target vocabulary (of size output_size) to a dense vector of size hidden_size.
        self.embedding = nn.Embedding(output_vocabulary_size, hidden_size)
        # Input size: hidden_size (embedding vector size).
        # Hidden size: hidden_size (dimensionality of GRU's internal state).
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        # Maps the GRU's hidden state to a vector of size output_size (corresponding to the vocabulary).
        self.out = nn.Linear(hidden_size, output_vocabulary_size)

    # encoder_outputs: The outputs of the encoder RNN (not used here but may be helpful in attention mechanisms).
    # encoder_hidden: The final hidden state of the encoder RNN (used to initialize the decoder's hidden state).
    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        # Extracts the batch size from encoder_outputs. Each batch contains multiple sequences.
        batch_size = encoder_outputs.size(0)
        # A tensor filled with the start-of-sequence (SOS) token, which initializes the decoding process.
        # Shape: [batch_size, 1] (one token per sequence).
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        # Sets the initial hidden state of the decoder to the final hidden state of the encoder. This links the encoding and decoding processes.
        decoder_hidden = encoder_hidden
        # A list to store the outputs (predictions) for each time step.
        decoder_outputs = []

        # Iterates over the maximum sequence length to decode each token one by one.
        for i in range(MAX_LENGTH):
            # Calls the forward_step method to produce the next token and update the hidden state.
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            # Appends the decoder output to the list of outputs.
            decoder_outputs.append(decoder_output)

            # If the target sequence (target_tensor) is provided, use the actual token from the target as the next input to the decoder.
            # During training
            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                # target_tensor[:, i]: Selects the i-th token for each sequence in the batch.
                # Unsqueeze(1): Adds a dimension to match the shape [batch_size, 1].
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                #  If no target is provided, use the decoder's own predictions as the next input.
                # Without teacher forcing: use its own predictions as the next input

                # decoder_output.topk(1): Selects the index of the highest probability token (predicted token).
                # this is not decoder outputs list!!!!!!!

                # decoder_output is the raw output from the decoder for the current time step. It has shape [batch_size, 1, output_size].
                # output_size is the size of the target vocabulary, and each element represents the unnormalized logit for each token in the vocabulary.
                # .topk(1) retrieves the highest value (the most likely token) along the last dimension (output_size).

                # topk returns two tensors:
                    # Values: The probability scores (not used here).
                    # Indices (topi): The token indices corresponding to the highest probability scores.
                _, topi = decoder_output.topk(1)

                # The topi tensor (indices of the predicted tokens) has shape [batch_size, 1].
                # squeeze(-1) removes the singleton dimension (1) at the last axis, resulting in a tensor of shape [batch_size].
                # Example:
                # Before squeezing: [[2], [4], [0]]
                # After squeezing: [2, 4, 0]

                # .detach():

                # Purpose: Detaches the tensor from the computation graph.
                # Normally, PyTorch keeps track of all operations on tensors to compute gradients during backpropagation. Here, we don't want gradients to flow through the prediction (because it's being used as an input for the next step, not part of the loss computation).
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input
        
        # Combines the outputs for all time steps into a single tensor of shape [batch_size, MAX_LENGTH, output_size].
        # this is the list!!
        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        # Converts raw scores into log-probabilities over the vocabulary for each token. This is useful for loss calculation.
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)

        # Outputs:
        # decoder_outputs: Log-probabilities over the vocabulary for the entire sequence.
        # decoder_hidden: The final hidden state of the decoder.
        # None: Placeholder for compatibility with training loops that expect additional outputs (e.g., attention weights).        
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        # Converts the input token index into its dense embedding vector.
        output = self.embedding(input)
        # Applies a ReLU activation to introduce non-linearity.
        output = F.relu(output)
        #Passes the embedding through the GRU, updating the hidden state.
        output, hidden = self.gru(output, hidden)
        # Maps the GRU output to a vector of size output_size (raw scores over the vocabulary).
        output = self.out(output)
        return output, hidden

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we\'ll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# Attention Decoder
# =================
#
# If only the context vector is passed between the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to \"focus\" on a different part of
# the encoder\'s outputs for every step of the decoder\'s own outputs.
# First we calculate a set of *attention weights*. These will be
# multiplied by the encoder output vectors to create a weighted
# combination. The result (called `attn_applied` in the code) should
# contain information about that specific part of the input sequence, and
# thus help the decoder choose the right output words.
#
# ![](https://i.imgur.com/1152PYf.png)
#
# Calculating the attention weights is done with another feed-forward
# layer `attn`, using the decoder\'s input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/attention-decoder-network.png)
#
# Bahdanau attention, also known as additive attention, is a commonly used
# attention mechanism in sequence-to-sequence models, particularly in
# neural machine translation tasks. It was introduced by Bahdanau et al.
# in their paper titled [Neural Machine Translation by Jointly Learning to
# Align and Translate](https://arxiv.org/pdf/1409.0473.pdf). This
# attention mechanism employs a learned alignment model to compute
# attention scores between the encoder and decoder hidden states. It
# utilizes a feed-forward neural network to calculate alignment scores.
#
# However, there are alternative attention mechanisms available, such as
# Luong attention, which computes attention scores by taking the dot
# product between the decoder hidden state and the encoder hidden states.
# It does not involve the non-linear transformation used in Bahdanau
# attention.
#
# In this tutorial, we will be using Bahdanau attention. However, it would
# be a valuable exercise to explore modifying the attention mechanism to
# use Luong attention.

# %%
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.Wa = nn.Linear(hidden_size, hidden_size)
        self.Ua = nn.Linear(hidden_size, hidden_size)
        self.Va = nn.Linear(hidden_size, 1)

    def forward(self, query, keys):
        scores = self.Va(torch.tanh(self.Wa(query) + self.Ua(keys)))
        scores = scores.squeeze(2).unsqueeze(1)

        weights = F.softmax(scores, dim=-1)
        context = torch.bmm(weights, keys)

        return context, weights

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1):
        super(AttnDecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attention = BahdanauAttention(hidden_size)
        self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        attentions = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden, attn_weights = self.forward_step(
                decoder_input, decoder_hidden, encoder_outputs
            )
            decoder_outputs.append(decoder_output)
            attentions.append(attn_weights)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        attentions = torch.cat(attentions, dim=1)

        return decoder_outputs, decoder_hidden, attentions


    def forward_step(self, input, hidden, encoder_outputs):
        embedded =  self.dropout(self.embedding(input))

        query = hidden.permute(1, 0, 2)
        context, attn_weights = self.attention(query, encoder_outputs)
        input_gru = torch.cat((embedded, context), dim=2)

        output, hidden = self.gru(input_gru, hidden)
        output = self.out(output)

        return output, hidden, attn_weights

# %% [markdown]
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
# <p>There are other forms of attention that work around the lengthlimitation by using a relative position approach. Read about "localattention" in <a href="https://arxiv.org/abs/1508.04025">Effective Approaches to Attention-based Neural MachineTranslation</a>.</p>
# </div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

def get_dataloader(batch_size):
    input_lang, output_lang, pairs = prepareData('eng', 'fra', True)

    n = len(pairs)
    input_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)
    target_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)

    for idx, (inp, tgt) in enumerate(pairs):
        inp_ids = indexesFromSentence(input_lang, inp)
        tgt_ids = indexesFromSentence(output_lang, tgt)
        inp_ids.append(EOS_token)
        tgt_ids.append(EOS_token)
        input_ids[idx, :len(inp_ids)] = inp_ids
        target_ids[idx, :len(tgt_ids)] = tgt_ids

    train_data = TensorDataset(torch.LongTensor(input_ids).to(device),
                               torch.LongTensor(target_ids).to(device))

    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
    return input_lang, output_lang, train_dataloader

# %% [markdown]
# Training the Model
# ==================
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the `<SOS>` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# \"Teacher forcing\" is the concept of using the real target outputs as
# each next input, instead of using the decoder\'s guess as the next
# input. Using teacher forcing causes it to converge faster but [when the
# trained network is exploited, it may exhibit
# instability](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf).
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation
# -intuitively it has learned to represent the output grammar and can
# \"pick up\" the meaning once the teacher tells it the first few words,
# but it has not properly learned how to create the sentence from the
# translation in the first place.
#
# Because of the freedom PyTorch\'s autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# `teacher_forcing_ratio` up to use more of it.

# %%
def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion):

    total_loss = 0
    for data in dataloader:
        input_tensor, target_tensor = data

        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

        loss = criterion(
            decoder_outputs.view(-1, decoder_outputs.size(-1)),
            target_tensor.view(-1)
        )
        loss.backward()

        encoder_optimizer.step()
        decoder_optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -   Start a timer
# -   Initialize optimizers and criterion
# -   Create set of training pairs
# -   Start empty losses array for plotting
#
# Then we call `train` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.001,
               print_every=100, plot_every=100):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()

    for epoch in range(1, n_epochs + 1):
        loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if epoch % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, epoch / n_epochs),
                                        epoch, epoch / n_epochs * 100, print_loss_avg))

        if epoch % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ================
#
# Plotting is done with matplotlib, using the array of loss values
# `plot_losses` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder\'s predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder\'s
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, decoder_attn

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
# def evaluateRandomly(encoder, decoder, n=10):
#     for i in range(n):
#         pair = random.choice(pairs)
#         print('>', pair[0])
#         print('=', pair[1])
#         output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
#         output_sentence = ' '.join(output_words)
#         print('<', output_sentence)
#         print('')


def evaluateRandomly(encoder, decoder, n=10):
    correct_count = 0  # Initialize the counter for correct translations

    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
        output_sentence = ' '.join(output_words).replace('<EOS>', '').strip()
        print('<', output_sentence)

        # Check if the model's output matches the target translation
        if output_sentence == pair[1]:
            print("Correct")
            correct_count += 1
        else:
            print("Incorrect")

        print('')  # Empty line for readability

    # Calculate the percentage of correct translations
    accuracy = (correct_count / n) * 100
    print(f"Accuracy: {accuracy:.2f}% ({correct_count}/{n})")

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we\'ll get
# some reasonable results.
#
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
# <p>If you run this notebook you can train, interrupt the kernel,evaluate, and continue training later. Comment out the lines where theencoder and decoder are initialized and run <code>trainIters</code> again.</p>
# </div>

# %%
hidden_size = 128
batch_size = 32

input_lang, output_lang, train_dataloader = get_dataloader(batch_size)

encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)

print(encoder)
print(decoder)

train(train_dataloader, encoder, decoder, 80, print_every=5, plot_every=5)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 11445 sentence pairs
# Counting words...
# Counted words:
# fra 4601
# eng 2991
# EncoderRNN(
#   (embedding): Embedding(4601, 128)
#   (gru): GRU(128, 128, batch_first=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# AttnDecoderRNN(
#   (embedding): Embedding(2991, 128)
#   (attention): BahdanauAttention(
#     (Wa): Linear(in_features=128, out_features=128, bias=True)
#     (Ua): Linear(in_features=128, out_features=128, bias=True)
#     (Va): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (gru): GRU(256, 128, batch_first=True)
#   (out): Linear(in_features=128, out_features=2991, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# 1m 2s (- 15m 30s) (5 6%) 1.5272
# 2m 1s (- 14m 8s) (10 12%) 0.6625
# 2m 56s (- 12m 45s) (15 18%) 0.3359
# 3m 52s (- 11m 37s) (20 25%) 0.1849
# 5m 3s (- 11m 8s) (25 31%) 0.1161
# 6m 6s (- 10m 11s) (30 37%) 0.0823
# 7m 25s (- 9m 32s) (35 43%) 0.0627
# 8m 25s (- 8m 25s) (40 50%) 0.0517
# 9m 28s (- 7m 21s) (45 56%) 0.0456
# 10m 28s (- 6m 16s) (50 62%) 0.0403
# 11m 27s (- 5m 12s) (55 68%) 0.0367
# 12m 35s (- 4m 11s) (60 75%) 0.0351
# 13m 42s (- 3m 9s) (65 81%) 0.0329
# 14m 45s (- 2m 6s) (70 87%) 0.0312
# 15m 47s (- 1m 3s) (75 93%) 0.0308
# 16m 53s (- 0m 0s) (80 100%) 0.0295

# %% [markdown]
# Set dropout layers to `eval` mode

# %%
encoder.eval()
decoder.eval()
evaluateRandomly(encoder, decoder, 2000)
# Out:
# > tu gaspilles des munitions
# = you re wasting ammo
# < you re wasting ammo
# Correct
#
# > vous avez tous deux faux
# = you are both in the wrong
# < you are both in the wrong house
# Incorrect
#
# > c est un vrai gentilhomme
# = he is a true gentleman
# < he is a true gentleman
# Correct
#
# > il connait le maire
# = he is acquainted with the mayor
# < he is acquainted with the mayor
# Correct
#
# > elles ne vont pas revenir
# = they re not coming back
# < they re not coming back
# Correct
#
# > tu es tres attirante
# = you re very attractive
# < you re very attractive impressed
# Incorrect
#
# > je me bats
# = i m fighting
# < i m fighting into fighting
# Incorrect
#
# > nous sommes dignes de confiance
# = we re trustworthy
# < we re trustworthy
# Correct
#
# > vous etes tres marrant
# = you re very funny
# < you re very funny
# Correct
#
# > je suis tres contente de vous revoir
# = i m very glad to see you again
# < i m very glad to see you again
# Correct
#
# > vous etes pleins de ressources
# = you re very resourceful
# < you re resourceful
# Incorrect
#
# > vous etes vraiment incroyables
# = you re really incredible
# < you re really incredible
# Correct
#
# > vous etes fort talentueuses
# = you re very talented
# < you re very talented me
# Incorrect
#
# > vous etes gare en double file
# = you re double parked
# < you re double parked with me
# Incorrect
#
# > je suis humain
# = i am human
# < i am human
# Correct
#
# > nous ne sommes pas prisonniers
# = we re not prisoners
# < we re not prisoners
# Correct
#
# > vous avez toujours quelque chose a me reprocher
# = you are always finding fault with me
# < you are always finding fault with me
# Correct
#
# > je ne suis pas decourage
# = i m not discouraged
# < i m not discouraged
# Correct
#
# > elles sont juste derriere toi
# = they re right behind you
# < they re right behind you
# Correct
#
# > il a huit ans
# = he s eight years old
# < he is eight years old
# Incorrect
#
# > il est un peu reveche
# = he s a bit rough around the edges
# < he s a bit rough around the edges
# Correct
#
# > je ne me sens pas offensee
# = i m not offended
# < i m not offended aren t offended
# Incorrect
#
# > elle est bonne a tomber raide
# = she s drop dead gorgeous
# < she s drop dead gorgeous
# Correct
#
# > je suis fauche
# = i m broke
# < i m broke
# Correct
#
# > je vis mon reve
# = i m living my dream
# < i m living my dream s my house
# Incorrect
#
# > j en suis sure
# = i m sure
# < i m sure about sure
# Incorrect
#
# > je suis volontaire
# = i am a volunteer
# < i am a volunteer
# Correct
#
# > je fais mes devoirs
# = i m doing my homework
# < i m doing my homework
# Correct
#
# > nous ne sommes pas contents
# = we re not happy
# < we re not happy with she
# Incorrect
#
# > il est actuellement a l exterieur
# = he s out now
# < he s out now
# Correct
#
# > elle est bonne nageuse
# = she is a good swimmer
# < she is a good swimmer
# Correct
#
# > nous en sommes tres satisfaits
# = we re very satisfied with it
# < we re very satisfied with it
# Correct
#
# > vous n etes pas les bienvenues ici
# = you re not welcome here
# < you re not welcome here
# Correct
#
# > je ne lui suis pas lie
# = i am not acquainted with him
# < i am not acquainted with him
# Correct
#
# > nous allons manger tout de suite
# = we re going to eat right now
# < we re going to eat right now
# Correct
#
# > c est une amie a moi
# = she is a friend of mine
# < she s a friend of mine
# Incorrect
#
# > tu es creatif
# = you re creative
# < you re creative
# Correct
#
# > elle est super
# = she s awesome
# < she s awesome
# Correct
#
# > vous etes tres marrante
# = you re very funny
# < you re very funny aren t you
# Incorrect
#
# > vous commettez une grosse erreur
# = you re making a big mistake
# < you re making a big risk an idiot
# Incorrect
#
# > c est une fille blonde
# = she is a blonde girl
# < she is a blonde girl
# Correct
#
# > tu fais tout ce que tu peux
# = you re doing all you can
# < you re doing all you can
# Correct
#
# > on te regarde
# = you re being watched
# < you re being watched
# Correct
#
# > je suppose que c est votre pere
# = i m assuming this is your father
# < i m assuming this is your father
# Correct
#
# > vous n etes pas les bienvenues ici
# = you re not welcome here
# < you re not welcome here
# Correct
#
# > tu es vilaine
# = you are naughty
# < you are naughty
# Correct
#
# > je ne suis pas trop fatigue
# = i am not too tired
# < i m not too tired
# Incorrect
#
# > je ne vends rien du tout
# = i m not selling anything
# < i m not selling anything
# Correct
#
# > il est trop timide pour parler aux filles
# = he is too shy to talk to girls
# < he is too shy to talk to girls
# Correct
#
# > il vous attend chez moi
# = he s waiting for you at home
# < he s waiting for you at home
# Correct
#
# > elle est toujours au bas de la classe
# = she is always at the bottom of the class
# < she is always at the bottom of the class
# Correct
#
# > elle est habituee a se lever tot
# = she s accustomed to getting up early
# < she s accustomed to getting up early
# Correct
#
# > vous allez perdre
# = you re going to lose
# < you re going to lose any pain
# Incorrect
#
# > ils sont sur le point de partir
# = they re about to leave
# < they re about to leave
# Correct
#
# > vous etes deloyale
# = you re disloyal
# < you re disloyal
# Correct
#
# > je suis desole je ne peux pas t aider
# = i m sorry i can t help you
# < i m sorry i can t help you
# Correct
#
# > elle va rendre visite a sa grand mere samedi
# = she is going to visit her grandmother on saturday
# < she is going to visit her grandmother on saturday
# Correct
#
# > elles ne sont pas si mauvaises
# = they re not so bad
# < they re not so bad
# Correct
#
# > tu es nerveusement usee
# = you re a nervous wreck
# < you re a nervous wreck
# Correct
#
# > il est sur de reussir
# = he is sure to succeed
# < he is sure of success
# Incorrect
#
# > je vais attraper le bus suivant
# = i m going to catch the next bus
# < i m going to catch the next bus
# Correct
#
# > je n en suis pas sur
# = i am not certain about that
# < i m not sure about that
# Incorrect
#
# > tu me fais rougir
# = you re making me blush
# < you re making me blush
# Correct
#
# > je suis heureux d annoncer que nous avons gagne
# = i m happy to report that we won
# < i m happy to report that we won
# Correct
#
# > il craint de commettre des erreurs
# = he s afraid of making mistakes
# < he s afraid of making mistakes
# Correct
#
# > nous avons vraiment de la chance
# = we re really lucky
# < we re really lucky to be kind
# Incorrect
#
# > vous etes une menteuse
# = you re a liar
# < you re a liar liar
# Incorrect
#
# > nous recherchons un appartement avec deux chambres
# = we re looking for an apartment with two bedrooms
# < we re looking for an apartment with two bedrooms
# Correct
#
# > il a faim et soif
# = he s hungry and thirsty
# < he s hungry and thirsty and thirsty
# Incorrect
#
# > tu es medisant
# = you re being malicious
# < you re being malicious
# Correct
#
# > vous etes soucieuse n est ce pas ?
# = you re worried aren t you ?
# < you re worried aren t you ?
# Correct
#
# > nous sommes malchanceux
# = we re unlucky
# < we re unlucky
# Correct
#
# > je suis desireux de t aider
# = i am willing to help you
# < i am willing to help you
# Correct
#
# > elles sont heureuses
# = they re happy
# < i m sorry to finally feel guilty
# Incorrect
#
# > elle est une personne tres interessante
# = she s a very interesting person
# < she s a very interesting person
# Correct
#
# > vous cachez quelque chose
# = you re hiding something
# < you re hiding something
# Correct
#
# > nous sommes trop occupees
# = we re too busy
# < we re too busy
# Correct
#
# > tu es desormais une femme
# = you re a woman now
# < you re a woman now
# Correct
#
# > il n est pas la
# = he s not in
# < he isn t here
# Incorrect
#
# > tu es fantasque
# = you re temperamental
# < you re temperamental
# Correct
#
# > tu es adorable
# = you re adorable
# < you are adorable
# Incorrect
#
# > je suis plus rapide
# = i m faster
# < i m faster
# Correct
#
# > vous etes tres en colere
# = you re very angry
# < you re very angry
# Correct
#
# > tu es en meilleure forme que moi
# = you re in better shape than i am
# < you re in better shape than i am
# Correct
#
# > j emploie un nouvel ordinateur
# = i am using a new computer
# < i am using a new computer
# Correct
#
# > nous sommes intelligentes
# = we re smart
# < we re smart now
# Incorrect
#
# > il est deja la
# = he is already here
# < he is already much alive
# Incorrect
#
# > je suis toujours tres nerveux
# = i m always very nervous
# < i m always very nervous stuck
# Incorrect
#
# > vous etes tres elegants
# = you re very sophisticated
# < you re very religious
# Incorrect
#
# > je suis sur qu elle partira tot
# = i m sure she ll leave early
# < i m sure she ll leave early
# Correct
#
# > c est un chanteur aime de tous
# = he s a singer that s loved by everyone
# < he s a singer that s loved by everyone
# Correct
#
# > il est tenancier de bar
# = he s a bartender
# < he s a bartender
# Correct
#
# > nous sommes reconnaissants
# = we re grateful
# < we re grateful to us
# Incorrect
#
# > je suis content que tu m aies demande conseil
# = i m glad you asked me for advice
# < i m glad you asked me for advice
# Correct
#
# > je suis trop fatigue pour grimper
# = i am too tired to climb
# < i m too tired to climb
# Incorrect
#
# > je n en suis pas fiere
# = i m not proud of that
# < i m not proud of that
# Correct
#
# > c est une jumelle
# = she is a twin
# < she s a twin
# Incorrect
#
# > j ai honte de dire que c est vrai
# = i m ashamed to say that it s true
# < i m ashamed to say that it s true
# Correct
#
# > je ne suis pas parfaite
# = i m not perfect
# < i m not perfect
# Correct
#
# > tu as a nouveau tort
# = you re wrong again
# < you re wrong again
# Correct
#
# > vous n etes pas seuls
# = you re not alone
# < you aren t alone
# Incorrect
#
# > nous sommes attaquees
# = we re being attacked
# < we re being attacked
# Correct
#
# > je ne suis pas tres occupee
# = i m not very busy
# < i m not very busy
# Correct
#
# > c est un jeune homme prometteur
# = he is a promising young man
# < he is a promising young man
# Correct
#
# > il est a la recherche d un emploi
# = he s looking for a job
# < he is looking for a job
# Incorrect
#
# > c est vous le maitre
# = you re the master
# < you re the master
# Correct
#
# > je suis libre tous les jours sauf le lundi
# = i m free every day but monday
# < i m free every day but monday
# Correct
#
# > c est un adulte
# = he s a grown man
# < he s a grown man
# Correct
#
# > je suis trop vieille pour tom
# = i m too old for tom
# < i m too old for tom
# Correct
#
# > il le fait comme il faut
# = he s doing it right
# < he s doing it right
# Correct
#
# > je suis ici en tant que touriste
# = i m here as a tourist
# < i m here as a tourist
# Correct
#
# > tu n es plus mon ami
# = you re not my friend anymore
# < you re not my friend anymore
# Correct
#
# > je ne suis pas contente
# = i m not happy
# < i m not happy
# Correct
#
# > il est si mignon !
# = he s so cute
# < he s so cute !
# Incorrect
#
# > tu es tellement belle dans cette robe !
# = you re so beautiful in that dress
# < you re so beautiful in that dress
# Correct
#
# > elles sont onereuses
# = they re expensive
# < they re expensive
# Correct
#
# > nous ne sommes plus dans les annees quatre vingts
# = we re not in the s anymore
# < we re not in the s anymore
# Correct
#
# > vous etes deux fois plus forts que moi
# = you are twice as strong as i am
# < you are twice as strong as i am
# Correct
#
# > je suis creve
# = i am exhausted
# < i am tired
# Incorrect
#
# > j y vais seul
# = i m going there alone
# < i m going there alone here
# Incorrect
#
# > nous ne nous battons pas
# = we re not fighting
# < we re not fighting things
# Incorrect
#
# > vous etes fous
# = you re demented
# < you re demented
# Correct
#
# > j oublie deja le visage de ma grand mere
# = i am already forgetting my grandmother s face
# < i am already forgetting my grandmother s face
# Correct
#
# > je suis lave
# = i m cleaned out
# < i m cleaned out of washing
# Incorrect
#
# > il est completement fou
# = he s an absolute fool
# < he s an absolute crazy
# Incorrect
#
# > nous sommes en train de nous en charger
# = we re handling it
# < we re handling it
# Correct
#
# > je suis heureux que tu l aies aime
# = i m happy you liked it
# < i m glad you liked it
# Incorrect
#
# > nous allons fouiller la totalite du bateau
# = we re going to search the whole ship
# < we re going to search the whole ship
# Correct
#
# > vous etes fort bon
# = you re very good
# < you re very good good
# Incorrect
#
# > je vais etre papa
# = i m going to be a father
# < i m going to be a father is
# Incorrect
#
# > je ne le gobe toujours pas
# = i m still not buying it
# < i m still not buying it
# Correct
#
# > je ne suis pas ta servante
# = i m not your maid
# < i m not your servant
# Incorrect
#
# > je ne suis pas desesperee
# = i m not desperate
# < i m not desperate
# Correct
#
# > je suis tres mediocre en sport
# = i am very poor at sports
# < i am very poor at sports
# Correct
#
# > vous etes mes amis tous les deux
# = you re my friends both of you
# < you re my friends both of you
# Correct
#
# > il travaille sur un nouveau roman
# = he is working on a new novel
# < he is working on a new novel
# Correct
#
# > j en ai marre des devoirs !
# = i m fed up with homework
# < i m fed up with homework
# Correct
#
# > c est mon associe
# = he s my partner
# < he s my partner responsible
# Incorrect
#
# > tu n es pas notre amie
# = you are not our friend
# < you are not our friend of a doctor
# Incorrect
#
# > vous n etes pas autorisee a vous garer ici
# = you re not allowed to park here
# < you re not allowed to park here
# Correct
#
# > je pense cloturer mon compte d epargne
# = i am thinking of closing my savings account
# < i am thinking of closing my savings account
# Correct
#
# > je suis gourmand
# = i m greedy
# < i m greedy
# Correct
#
# > je suis heureux d entendre parler de ton succes
# = i m glad to hear of your success
# < i m glad to hear of your success
# Correct
#
# > tu fais la bonne chose
# = you re doing the right thing
# < you re doing the right thing
# Correct
#
# > on s eclate
# = we re having a blast
# < i m dying for him
# Incorrect
#
# > il est parfait en tout
# = he s perfect at everything
# < he s perfect at everything alive
# Incorrect
#
# > elles sont mignonnes
# = they re cute
# < they re cute
# Correct
#
# > je suis a vous
# = i m yours
# < i m yours to you
# Incorrect
#
# > nous regrettons de ne pas pouvoir vous aider
# = we are sorry we can t help you
# < we re sorry we can t help you
# Incorrect
#
# > tu es un idiot
# = you re an idiot
# < you re an idiot !
# Incorrect
#
# > elle a tres peur du noir
# = she is very afraid of the dark
# < she is very afraid of the dark
# Correct
#
# > je suis vraiment fatigue
# = i m really tired
# < i m really tired tired
# Incorrect
#
# > c est un homme de grand talent
# = he is a man of great ability
# < he is a man of great ability
# Correct
#
# > nous sommes juste fatiguees
# = we re just tired
# < we re just tired
# Correct
#
# > je suis sur qu il va reussir son examen
# = i am sure of his passing the examination
# < i am sure of his passing the examination
# Correct
#
# > je suis tres en faveur de cela
# = i m very much in favor of this
# < i m very much in favor of this
# Correct
#
# > vous etes trop sensible a la critique
# = you are too sensitive to criticism
# < you are too sensitive to criticism
# Correct
#
# > vous etes precisement l homme que je veux voir
# = you are the very man i want to see
# < you re just the man i want to see
# Incorrect
#
# > je suis dans la voiture
# = i m in the car
# < i m in the car car
# Incorrect
#
# > vous etes plus grands que moi
# = you re taller than i am
# < you re taller than me
# Incorrect
#
# > elles sont semblables
# = they re similar
# < they re similar
# Correct
#
# > je suis fascinee par les chats
# = i m fascinated by cats
# < i m fascinated by cats
# Correct
#
# > vous avez parfaitement raison
# = you are absolutely right
# < you re totally right right
# Incorrect
#
# > tu as parfaitement raison
# = you re completely right
# < you re perfectly right
# Incorrect
#
# > vous en etes en partie responsables
# = you are in part responsible for it
# < you are in part responsible for it
# Correct
#
# > tu es difficile
# = you re fussy
# < you re fussy
# Correct
#
# > tu es idiot
# = you re being silly
# < you re being silly
# Correct
#
# > je suis entre deux emplois
# = i m between jobs
# < i m between jobs
# Correct
#
# > il quitte narita pour hawaii ce soir
# = he is leaving narita for hawaii this evening
# < he is leaving narita for hawaii this evening
# Correct
#
# > je ne suis plus en colere apres vous
# = i m no longer angry at you
# < i m no longer angry at you
# Correct
#
# > je suis desole mon pere est dehors
# = i m sorry my father is out
# < i m sorry my father is out
# Correct
#
# > je suis tetu
# = i m stubborn
# < i m stubborn
# Correct
#
# > nous sommes un peu en retard
# = we re a bit late
# < we re a bit late
# Correct
#
# > il est accro a la malbouffe
# = he s addicted to junk food
# < he s addicted to junk food
# Correct
#
# > elles sont chanceuses d etre en vie
# = they re lucky to be alive
# < they re lucky to be alive
# Correct
#
# > je suis tout seul
# = i m all by myself
# < i m all alone alone
# Incorrect
#
# > vous etes imprudents
# = you re foolish
# < you re the one
# Incorrect
#
# > je ne suis pas vraiment inquiet
# = i m not really worried
# < i m not really worried about it
# Incorrect
#
# > je ne suis pas paranoiaque
# = i m not paranoid
# < i m not paranoid
# Correct
#
# > nous sommes amies
# = we re friends
# < we re friends
# Correct
#
# > vous n etes pas invitee
# = you aren t invited
# < you aren t invited
# Correct
#
# > je suis heureux de vous avoir invitee
# = i m glad i invited you
# < i m glad i invited you
# Correct
#
# > vous etes tres genereuse
# = you re very generous
# < you re very generous
# Correct
#
# > c est une gentille fille
# = she is a kind girl
# < she is a very kind girl
# Incorrect
#
# > je suis pret a affronter n importe quel defi
# = i m ready to face any challenge
# < i m ready to face any challenge
# Correct
#
# > je ne reviens pas
# = i m not coming back
# < i m not coming not going outside
# Incorrect
#
# > je ne suis pas d humeur a blaguer
# = i am in no mood for joking
# < i am in no mood for joking
# Correct
#
# > je ne suis pas quelqu un de patient
# = i m not a patient person
# < i m not a patient person
# Correct
#
# > je me suis amendee
# = i m reformed
# < i m reformed
# Correct
#
# > tu es tres marrante
# = you re very funny
# < you re very funny aren t you
# Incorrect
#
# > elle n est pas confiante en l avenir
# = she s not confident about the future
# < she s not confident about the future
# Correct
#
# > je plie ma robe
# = i am folding my dress
# < i am folding my dress
# Correct
#
# > ils sont russes
# = they are russian
# < they are russian
# Correct
#
# > il est precisement celui que tu cherches
# = he is precisely the one you are looking for
# < he is precisely the one you are looking for
# Correct
#
# > je crains que ce ne soit pas si simple
# = i m afraid it s not that simple
# < i m afraid it s not that simple
# Correct
#
# > je suis heureux que tu l aies apprecie
# = i m glad you liked it
# < i m glad you liked it
# Correct
#
# > je suis desole je ne parle pas francais
# = i m sorry i don t speak french
# < i m sorry i don t speak french
# Correct
#
# > je viens d egypte
# = i am from egypt
# < i am from egypt
# Correct
#
# > je suis ravi de faire votre connaissance
# = i m very pleased to meet you
# < i m very pleased to meet you
# Correct
#
# > ils travaillent tous les deux a l animalerie
# = they are both working at the pet store
# < they are both working at the pet store
# Correct
#
# > il est recherche par la police
# = he is hunted by the police
# < he is hunted by the police
# Correct
#
# > tu es une personne execrable
# = you re a terrible person
# < you re a terrible person
# Correct
#
# > je suis tellement embarrasse
# = i m so embarrassed
# < i m so embarrassed you
# Incorrect
#
# > il est en train de prendre une douche
# = he s taking a shower
# < he s taking a shower
# Correct
#
# > je suis agriculteur
# = i m a farmer
# < i m a farmer
# Correct
#
# > je n en ai pas encore termine
# = i m not done yet
# < i m not done yet
# Correct
#
# > je n en suis plus aussi certaine
# = i m not so sure anymore
# < i m not so sure anymore
# Correct
#
# > tu es un de ces dragueurs !
# = you re such a flirt
# < you re such a flirt
# Correct
#
# > il n est pas coupable de meurtre
# = he is not guilty of murder
# < he is not guilty of murder
# Correct
#
# > elle devient de plus en plus jolie
# = she is getting prettier and prettier
# < she is getting prettier and prettier
# Correct
#
# > je suis en train de travailler
# = i m working
# < i am working
# Incorrect
#
# > je ne suis pas patient
# = i m not patient
# < i m not patient
# Correct
#
# > je suis sur que nous pouvons arranger cela
# = i m sure we can work this out
# < i m sure we can work this out
# Correct
#
# > je suis un bon cuisinier
# = i m a good cook
# < i m a good cook as a good cook
# Incorrect
#
# > je ne suis pas encore mort
# = i m not dead yet
# < i m not dead yet
# Correct
#
# > je ne suis pas celle que tu penses
# = i m not who you think i am
# < i m not who you think i am
# Correct
#
# > ils sont conscients des difficultes
# = they are aware of the difficulties
# < they are aware of the difficulties
# Correct
#
# > vous etes un menteur
# = you re a liar
# < you re a liar liar
# Incorrect
#
# > nous sommes toujours en vie
# = we re still alive
# < we re still alive
# Correct
#
# > tu es mon meilleur ami
# = you re my best friend
# < you are my best friend good looking
# Incorrect
#
# > je ne suis pas petite
# = i m not short
# < i m not short morning
# Incorrect
#
# > je commence a la detester
# = i m beginning to hate her
# < i m beginning to hate her
# Correct
#
# > tu as trop confiance en toi
# = you re overconfident
# < you re overconfident
# Correct
#
# > je ne suis pas abruti
# = i m not dumb
# < i m not dumb to pry
# Incorrect
#
# > il a peur des chiens
# = he is afraid of dogs
# < he is afraid of dogs dogs
# Incorrect
#
# > je commence a peine
# = i m just beginning
# < i m beginning to understand why
# Incorrect
#
# > on n a pas besoin de nous
# = we re not needed
# < we re not needed
# Correct
#
# > je suis desole si je vous ai derangee
# = i m sorry if i disturbed you
# < i m sorry if i disturbed you
# Correct
#
# > vous n etes pas mortes
# = you re not dead
# < you re not dead yet
# Incorrect
#
# > tu es celle la
# = you are the one
# < you are the one who trained me
# Incorrect
#
# > tu agis comme un enfant
# = you re acting like a child
# < you re acting like a child
# Correct
#
# > je ne frime pas
# = i m not bragging
# < i m not bragging not bragging
# Incorrect
#
# > nous ne sommes pas les bienvenues
# = we re not welcome
# < we re not welcome
# Correct
#
# > elles sont juste pour toi
# = they re just for you
# < they re just for you
# Correct
#
# > je tente de vous parler
# = i m trying to talk to you
# < i m trying to talk to you to you
# Incorrect
#
# > c est une coriace
# = she s a tough one
# < she s a tough one
# Correct
#
# > il a peur de la mort
# = he is afraid of death
# < he is afraid of death
# Correct
#
# > il est deja marie
# = he s already married
# < he s already married
# Correct
#
# > il manque de pratique
# = he s out of practice
# < he s out of practice
# Correct
#
# > il est en train d etudier
# = he s studying
# < he s studying
# Correct
#
# > vous etes chanceuses
# = you re fortunate
# < you re fortunate
# Correct
#
# > vous etes faible
# = you re weak
# < you re weak
# Correct
#
# > je suis ici pour ecouter
# = i m here to listen
# < i m here to listen listening to you
# Incorrect
#
# > je te suis reconnaissant pour ta gentillesse
# = i am grateful to you for your kindness
# < i am grateful to you for your kindness
# Correct
#
# > nous sommes fatigues
# = we re tired
# < we re tired of tired
# Incorrect
#
# > tu es tres peureuse
# = you re very timid
# < you re very very timid
# Incorrect
#
# > je n en suis plus aussi certaine
# = i m not so sure anymore
# < i m not so sure anymore
# Correct
#
# > nous sommes toutes folles
# = we re all crazy
# < we re all crazy
# Correct
#
# > je ne vais vous le montrer qu une fois
# = i m only going to show you once
# < i m only going to show you once
# Correct
#
# > c est une personne tres sympa
# = she is a very nice person
# < she is a very nice person here
# Incorrect
#
# > je ne suis pas sure d etre prete
# = i m not sure i m ready
# < i m not sure i m ready
# Correct
#
# > vous etes la seule desormais pour moi
# = you re the only one for me now
# < you re the only one for me now
# Correct
#
# > vous etes branche
# = you re fashionable
# < you re fashionable
# Correct
#
# > elle vous attend a la maison
# = she s waiting for you at home
# < she s waiting for you at home
# Correct
#
# > il est scientifique
# = he is a scientist
# < he is a scientist scientist
# Incorrect
#
# > c est un expert a la fronde
# = he s an expert with a slingshot
# < he s an expert with a slingshot
# Correct
#
# > personne n est trop vieux pour apprendre
# = you re never too old to learn
# < you re never too old to learn
# Correct
#
# > je suis pour toujours votre debiteur
# = i am forever in your debt
# < i am forever in your debt
# Correct
#
# > je suis celui qui prend les decisions
# = i m the one who makes the decisions
# < i m the one who makes the decisions
# Correct
#
# > je suis contraint a le faire
# = i am forced to do it
# < i am forced to do it
# Correct
#
# > il va se faire virer
# = he s going to get fired
# < he s going to get fired to get fired
# Incorrect
#
# > je suis loin d etre heureux de cette situation
# = i m far from happy about this situation
# < i m far from happy about this situation
# Correct
#
# > il est fort courageux
# = he is very brave
# < he is good very brave
# Incorrect
#
# > nous sommes flexibles
# = we re adaptable
# < we re adaptable my sister
# Incorrect
#
# > elle a une forte volonte
# = she s strong willed
# < she s strong willed loud
# Incorrect
#
# > je suis ici n est ce pas ?
# = i m here aren t i ?
# < i m here aren t i ?
# Correct
#
# > ce ne sont pas les miens
# = they re not mine
# < they re not mine
# Correct
#
# > je suis aussi curieuse que vous
# = i m as curious as you are
# < i m as curious as you are
# Correct
#
# > je suis epuise
# = i m worn out
# < i am exhausted
# Incorrect
#
# > je suis aussi agee que vous
# = i m as old as you
# < i m as old as you
# Correct
#
# > je suis heureux d etre rentre
# = i m happy to be back
# < i m glad i left boston
# Incorrect
#
# > vous n etes pas cense fumer ici
# = you are not supposed to smoke here
# < you are not supposed to smoke here
# Correct
#
# > je ne suis pas payee pour faire cela
# = i m not paid to do that
# < i m not paid to do that
# Correct
#
# > c est un ecrivain tres imaginatif
# = he is a very imaginative writer
# < he is a very imaginative writer
# Correct
#
# > nous avons des prejuges
# = we re prejudiced
# < we re biased
# Incorrect
#
# > nous prenons le controle
# = we re taking over
# < we re taking wasting town
# Incorrect
#
# > elle pleure
# = she is crying
# < she is crying
# Correct
#
# > tu es fabuleux
# = you are fabulous
# < you are fabulous
# Correct
#
# > je m ennuie faisons quelque chose !
# = i m bored let s do something
# < i m bored let s do something else
# Incorrect
#
# > il est sur le point de s en aller
# = he s about to leave
# < he s about to go
# Incorrect
#
# > je suis contre
# = i m against it
# < i m against it against it
# Incorrect
#
# > vous etes bonnes
# = you are good
# < you are good a good student
# Incorrect
#
# > je vais tout a fait bien maintenant
# = i am quite all right now
# < i am quite all right now
# Correct
#
# > vous plaisantez bien sur
# = you re joking of course
# < you re joking of course
# Correct
#
# > je suis ravi de te voir
# = i m pleased to see you
# < i m pleased to see you
# Correct
#
# > c est un employe tres travailleur
# = he s a very hard worker
# < he s a very hard worker
# Correct
#
# > tu es celui qui m a formee
# = you re the one who trained me
# < you re the one who trained me
# Correct
#
# > j ai la frousse
# = i m jittery
# < i m jittery
# Correct
#
# > je suis votre medecin
# = i m your doctor
# < i m your doctor a doctor
# Incorrect
#
# > il ne fait pas partie de notre groupe
# = he s not in our group
# < he s not in our group
# Correct
#
# > je suis aussi perplexe que vous l etes
# = i m just as confused as you are
# < i m just as confused as you are
# Correct
#
# > il est maintenant etudiant a la fac
# = he s now a college student
# < he is now a college student
# Incorrect
#
# > je suis vraiment heureux d entendre ca
# = i m really glad to hear that
# < i m really glad to hear that
# Correct
#
# > tu n es pas des leurs si ?
# = you re not one of them are you ?
# < you re not one of them are you ?
# Correct
#
# > je n ai pas peur de la mort
# = i m not afraid of death
# < i m not afraid of death
# Correct
#
# > il n est pas toujours chez lui le dimanche
# = he s not always at home on sundays
# < he s not always at home on sundays
# Correct
#
# > tu es celui qui m a forme
# = you re the one who trained me
# < you re the one who trained me
# Correct
#
# > elle n a peur de rien
# = she is not afraid of anything
# < she isn t afraid of anything
# Incorrect
#
# > je ne suis pas decourage
# = i m not discouraged
# < i m not discouraged
# Correct
#
# > je suis en train de tomber amoureux de vous
# = i m falling in love with you
# < i m falling in love with you
# Correct
#
# > c est un ange
# = she s an angel
# < he s an angel sweater
# Incorrect
#
# > j irai a izu pendant le week end
# = i m going to izu over the weekend
# < i m going to izu over the weekend
# Correct
#
# > il est en train de pleurer
# = he s crying
# < he s crying
# Correct
#
# > je suis tres satisfait de mon achat
# = i m very happy with my purchase
# < i m very happy with my purchase
# Correct
#
# > tu es fort astucieuse
# = you re very astute
# < you re very astute
# Correct
#
# > nous sommes les meilleurs amis
# = we re best friends
# < we are as good guys
# Incorrect
#
# > je suis trop vieille pour tom
# = i m too old for tom
# < i m too old for tom
# Correct
#
# > nous sommes australiennes
# = we are australian
# < we are australians
# Incorrect
#
# > je suis certain
# = i m certain
# < i m sure
# Incorrect
#
# > c est toi qui m as forme
# = you re the one who trained me
# < you re the one who trained me
# Correct
#
# > tu es le champion n est ce pas ?
# = you re the champion aren t you ?
# < you re the champion aren t you ?
# Correct
#
# > je suis ton meilleur ami
# = i m your best friend
# < i m your best friend s place
# Incorrect
#
# > il est capable de faire une chose pareille
# = he is capable of doing such a thing
# < he is capable of doing such a thing
# Correct
#
# > elle est tres fachee apres moi
# = she is very annoyed with me
# < she is very annoyed with me
# Correct
#
# > tu es fort elegant
# = you re very stylish
# < you re very sophisticated
# Incorrect
#
# > ils sont vraiment intimes
# = they re really tight
# < they re really tight drunk
# Incorrect
#
# > nous sommes tres reconnaissants pour votre hospitalite
# = we re very grateful for your hospitality
# < we re very grateful for your hospitality
# Correct
#
# > elle n est pas mon genre
# = she s not my type
# < she s not my type type
# Incorrect
#
# > c est une personne tres attentionnee
# = he is a very thoughtful person
# < he is a very thoughtful person
# Correct
#
# > je ne suis pas presse
# = i m in no hurry
# < i m in no hurry
# Correct
#
# > tu es talentueuse
# = you re talented
# < you re talented one talented
# Incorrect
#
# > je suis aussi curieuse que toi
# = i m as curious as you are
# < i m as curious as you are
# Correct
#
# > je suis mecontente
# = i m unhappy
# < i m unhappy
# Correct
#
# > nous sommes jalouses
# = we re jealous
# < we re jealous
# Correct
#
# > tu es tellement gentille !
# = you re so sweet
# < you re so sweet
# Correct
#
# > elles ont perdu l esprit
# = they re out of their minds
# < they re out of their minds
# Correct
#
# > nous sommes crevees
# = we re pooped
# < we re pooped
# Correct
#
# > ce n est pas une menteuse
# = she s not a liar
# < she s not a a liar
# Incorrect
#
# > je suis vraiment prudent
# = i m real careful
# < i m real careful impressed
# Incorrect
#
# > ils sont en colere apres toi
# = they re mad at you
# < they re mad at you
# Correct
#
# > je suis en sous vetements
# = i m in my underwear
# < i m in my underwear
# Correct
#
# > je ne suis pas un escroc
# = i m not a crook
# < i m not a crook
# Correct
#
# > c est un homme de parole
# = he s a man of his word
# < he is a man of his word
# Incorrect
#
# > j ai peur d avoir des problemes
# = i am afraid of having trouble
# < i am afraid of having trouble
# Correct
#
# > je suis desole de t avoir entrainee la dedans
# = i m sorry i dragged you into this
# < i m sorry i dragged you into this
# Correct
#
# > je suis francais
# = i am french
# < i am french french
# Incorrect
#
# > je ne suis pas qualifie pour faire ce travail
# = i m not qualified to do this job
# < i m not qualified to do this job
# Correct
#
# > je vous libere
# = i m letting you go
# < i m letting you go it you
# Incorrect
#
# > je conte une histoire
# = i am telling a story
# < i am telling a story wrong
# Incorrect
#
# > il oublie toujours des choses
# = he is always forgetting things
# < he is always forgetting things for things
# Incorrect
#
# > je vais l abattre
# = i m going to shoot him dead
# < i m going to shoot him dead to shoot him
# Incorrect
#
# > c est un garcon tres chouette
# = he s a very nice boy
# < he s a very nice boy
# Correct
#
# > je fais de mon mieux
# = i am doing my best
# < i m trying my best best
# Incorrect
#
# > c est un bon nageur
# = he is a good swimmer
# < he is a good swimmer
# Correct
#
# > je commence a me sentir desesperee
# = i m starting to feel desperate
# < i m beginning to feel desperate desperate
# Incorrect
#
# > elle cherche un meilleur emploi
# = she is after a better job
# < she is after a better job
# Correct
#
# > je vais etre en retard pour la reunion
# = i m going to be late for the meeting
# < i m going to be late for the meeting
# Correct
#
# > je suis sur que vous allez reussir
# = i m confident that you ll succeed
# < i m confident that you ll succeed
# Correct
#
# > j en ai fini de faire l andouille
# = i m done fooling around now
# < i m done fooling around now
# Correct
#
# > je suis ici
# = i am here
# < i am here
# Correct
#
# > je prends quelques jours de conge
# = i am taking a couple of days off
# < i am taking a couple of days off
# Correct
#
# > je dis la verite
# = i m truthful
# < i m truthful
# Correct
#
# > il est sur de son succes
# = he is sure of success
# < he is sure of his success
# Incorrect
#
# > vous etes tellement belle dans cette robe !
# = you re so beautiful in that dress
# < you re so beautiful in that dress
# Correct
#
# > nous n allons pas vous repondre
# = we re not going to do it
# < we re not gonna do it
# Incorrect
#
# > j ai bien peur de devoir y aller maintenant
# = i m afraid i have to go now
# < i m afraid i have to go now
# Correct
#
# > tu es veinarde
# = you re in luck
# < you re in luck
# Correct
#
# > vous m empoisonnez
# = you re poisoning me
# < you re poisoning me them
# Incorrect
#
# > tu es vieux
# = you re old
# < you re old
# Correct
#
# > je ne tiens pas en place
# = i m restless
# < i m restless
# Correct
#
# > il te regarde
# = he s looking at you
# < he s looking at you
# Correct
#
# > je suis un lyceen
# = i m a high school student
# < i m a high school student
# Correct
#
# > nous sommes amoureuses
# = we re in love
# < we re in love with love
# Incorrect
#
# > vous etes toutes pretes
# = you re all set
# < you re all set
# Correct
#
# > il est a tokyo
# = he is in tokyo
# < he is in tokyo
# Correct
#
# > je suis folle
# = i m crazy
# < i m crazy
# Correct
#
# > je suis celui qui a construit ceci
# = i m the one who built this
# < i m the one who built this
# Correct
#
# > j en ai marre de vos plaintes
# = i m getting tired of your complaints
# < i m getting tired of your complaints
# Correct
#
# > vous etes grandes
# = you are big
# < you are big trouble
# Incorrect
#
# > tu es vraiment egoiste
# = you re really selfish
# < you re really selfish
# Correct
#
# > moi aussi je suis professeur
# = i am a teacher too
# < i m a little disappointed with me
# Incorrect
#
# > j ai peur de ce que l instituteur dira
# = i am afraid of what the teacher will say
# < i am afraid of what the teacher will say
# Correct
#
# > il regarde toujours vers l avenir
# = he is always looking to the future
# < he is always looking to the future
# Correct
#
# > vous etes endurante
# = you re resilient
# < you re resilient
# Correct
#
# > je vais nager quotidiennement
# = i m going to swim every day
# < i m going to swim every day tomorrow
# Incorrect
#
# > t es bonne
# = you re good
# < you are good at this
# Incorrect
#
# > je repasse mes mouchoirs
# = i m ironing my handkerchiefs
# < i m ironing my handkerchiefs
# Correct
#
# > il n est pas en service aujourd hui
# = he is off duty today
# < he is off duty today
# Correct
#
# > je connais bien ce sujet
# = i am familiar with this subject
# < i am familiar with this subject
# Correct
#
# > j en ai assez d entendre ca
# = i am tired of hearing that
# < i am tired of hearing that
# Correct
#
# > nous manquons quelque chose ici
# = we re missing something here
# < we re missing something here
# Correct
#
# > il est le president du comite
# = he s the chairman of the committee
# < he s the chairman of the committee
# Correct
#
# > vous etes plein de talent
# = you re very talented
# < you re very talented me
# Incorrect
#
# > je meurs de faim !
# = i m starved
# < i m starving !
# Incorrect
#
# > tu es fort raffine
# = you re very sophisticated
# < you re very sophisticated
# Correct
#
# > je suis desolee de ne pas pouvoir t aider
# = i m sorry i can t help you
# < i m sorry i can t help you
# Correct
#
# > me voila satisfaite
# = i m contented
# < i m contented i love me
# Incorrect
#
# > vous etes tres belle
# = you re very beautiful
# < you re very beautiful in blue
# Incorrect
#
# > excusez moi de vous interrompre
# = i m sorry to interrupt you
# < i m sorry to interrupt you
# Correct
#
# > je suis en train de perdre mon temps
# = i am wasting my time
# < i am wasting my time
# Correct
#
# > je suis sur qu il viendra demain
# = i m sure he will come tomorrow
# < i m sure he will come tomorrow
# Correct
#
# > je suis si fatigue !
# = i m so tired !
# < i m so tired !
# Correct
#
# > nous sommes trop proches
# = we re too close
# < we re too close to fight
# Incorrect
#
# > vous etes marrants
# = you re funny
# < you re funny you
# Incorrect
#
# > j ai mal au c ur
# = i m hung over
# < i m hung over
# Correct
#
# > nous disposons d experience
# = we re experienced
# < we re experienced
# Correct
#
# > il grossit
# = he is putting on weight
# < he is putting on teaching
# Incorrect
#
# > vous etes marrants
# = you re funny
# < you re funny you
# Incorrect
#
# > tu n es pas le premier
# = you re not the first
# < you re not the first
# Correct
#
# > tu es libre de partir quand il te plaira
# = you are free to leave any time you wish
# < you are free to leave any time you wish
# Correct
#
# > tu es une sacree menteuse
# = you re such a liar
# < you re such a liar liar
# Incorrect
#
# > elle est trop bruyante
# = she s too loud
# < she s too too loud
# Incorrect
#
# > il va quitter chicago demain
# = he is leaving chicago tomorrow
# < he is leaving chicago tomorrow
# Correct
#
# > tu es astucieuse
# = you re crafty
# < you re crafty
# Correct
#
# > vous me bloquez la vue
# = you re blocking my view
# < you re blocking my view
# Correct
#
# > il est assis en tailleur
# = he is sitting cross legged
# < he is sitting cross legged late
# Incorrect
#
# > nous sommes faits l un pour l autre
# = we re meant for each other
# < we re meant for each other
# Correct
#
# > je suis musulman
# = i am a muslim
# < i am a muslim
# Correct
#
# > vous n etes pas contusionnes
# = you re not bruised
# < you re not bruised
# Correct
#
# > c est un frileux
# = he is very sensitive to cold
# < he is very sensitive to cold
# Correct
#
# > il est present a la reunion
# = he is present at the meeting
# < he is present at the meeting home
# Incorrect
#
# > je suis en retard pour l entrainement
# = i m late for practice
# < i m late for practice
# Correct
#
# > vous etes naives
# = you re naive
# < you re naive
# Correct
#
# > je suis accoutume au temps froid
# = i am accustomed to cold weather
# < i am used to working on sundays
# Incorrect
#
# > je ne suis pas chez moi
# = i m not home
# < i m not home
# Correct
#
# > il est un peu rugueux
# = he s a bit rough around the edges
# < he s a bit rough around the edges
# Correct
#
# > je viens de l exterieur de la ville
# = i m from out of town
# < i m from out of breath
# Incorrect
#
# > tu es celle qui m a entrainee
# = you re the one who trained me
# < you re the one who trained me
# Correct
#
# > je suis en salle de classe
# = i am in the classroom
# < i am in the classroom
# Correct
#
# > ce ne sont pas mes prisonniers
# = they re not my prisoners
# < they re not my prisoners
# Correct
#
# > nous sommes dans les temps
# = we re on schedule
# < we re on schedule terms
# Incorrect
#
# > je fais la diete
# = i m fasting
# < i m fasting
# Correct
#
# > j achete un chiot
# = i m buying a puppy
# < i m buying a puppy
# Correct
#
# > ce sont des espionnes
# = they re spies
# < they re spies
# Correct
#
# > on attend de vous que vous les aidiez
# = you re required to help them
# < you re required to help them
# Correct
#
# > il va se faire virer
# = he s going to get fired
# < he s going to get fired to get fired
# Incorrect
#
# > il depend completement de ses parents
# = he is totally dependent on his parents
# < he is totally dependent on his parents
# Correct
#
# > tu es l instituteur de mon enfant
# = you re my kid s teacher
# < you re my kid s teacher
# Correct
#
# > vous faites tout ce que vous pouvez
# = you re doing all you can
# < you re doing all you can
# Correct
#
# > je fais mon devoir
# = i m doing my duty
# < i m doing my duty
# Correct
#
# > je suis un nouvel etudiant
# = i m a new student
# < i m a new student
# Correct
#
# > nous sommes toujours en vie
# = we re still alive
# < we re still alive
# Correct
#
# > je suis surprise de vous voir
# = i m surprised to see you
# < i m surprised to see you
# Correct
#
# > ils ont peur de lui
# = they re afraid of him
# < they re afraid of him
# Correct
#
# > je ne suis pas desesperee
# = i m not desperate
# < i m not desperate
# Correct
#
# > je suis desolee si je vous ai derangees
# = i m sorry if i disturbed you
# < i m sorry if i disturbed you
# Correct
#
# > je suis a votre merci
# = i m at your mercy
# < i m willing to your help
# Incorrect
#
# > je commence a distinguer un schema
# = i m beginning to see a pattern
# < i m beginning to see a pattern
# Correct
#
# > elle porte un chapeau sympa
# = she s wearing a cool hat
# < she s wearing a cool hat
# Correct
#
# > il est probable que je suis juste paranoiaque la
# = i m probably just being paranoid
# < i m probably just being paranoid
# Correct
#
# > je suis desole de te creer tous ces soucis
# = i m sorry to cause you all this trouble
# < i m sorry to cause you all this trouble
# Correct
#
# > elles sont toutes fausses
# = they re all fake
# < they re all fake
# Correct
#
# > je commence a devenir curieux
# = i m beginning to get curious
# < i m beginning to get curious
# Correct
#
# > je suis desolee de t avoir blessee
# = i m sorry i hurt you
# < i m sorry i hurt you
# Correct
#
# > ils emmenent marie a la salle des urgences
# = they re taking mary to the emergency room
# < they re taking mary to the emergency room
# Correct
#
# > nous sommes prudentes
# = we re careful
# < we re careful
# Correct
#
# > vous etes avide
# = you re greedy
# < you re greedy
# Correct
#
# > elle est toujours occupee les jours de semaine
# = she s always busy on weekdays
# < she s always busy on weekdays
# Correct
#
# > c est loin d etre un gentleman
# = he is anything but a gentleman
# < he is anything but a gentleman
# Correct
#
# > je ne suis pas a la maison les dimanches
# = i m not home on sundays
# < i m not home on sundays
# Correct
#
# > j y travaille encore
# = i m still working on it
# < i m still working on it yet
# Incorrect
#
# > vous n etes pas aussi petites que moi
# = you aren t as short as i am
# < you aren t as short as i am
# Correct
#
# > je n irai pas au cinema demain
# = i m not going to the movies tomorrow
# < i m not going to the movies tomorrow
# Correct
#
# > elle est bienveillante
# = she is good natured
# < she is good natured
# Correct
#
# > il est embetant
# = he s annoying
# < you re annoying
# Incorrect
#
# > il est perdu dans ses pensees
# = he is lost in thought
# < he is lost in thought
# Correct
#
# > il est myope comme une taupe
# = he s as blind as a bat
# < he s as blind as a bat for town
# Incorrect
#
# > je suis etranger
# = i am a foreigner
# < i am a foreigner
# Correct
#
# > vous allez le regretter
# = you re going to regret this
# < you re going to regret this out
# Incorrect
#
# > tu passes trop de temps a regarder la tele
# = you re spending too much time watching tv
# < you re spending too much time watching tv
# Correct
#
# > il a decide de quitter la troupe
# = he s decided to leave the company
# < he s decided to leave the company
# Correct
#
# > je le fais pour toi
# = i m doing this for you
# < i m doing this for you
# Correct
#
# > je suis certain que tu reussiras
# = i m sure that you ll succeed
# < i m confident that you ll succeed
# Incorrect
#
# > je suis une artiste
# = i m an artist
# < i m one an artist
# Incorrect
#
# > je suis fatigue de toutes ces reflexions
# = i m tired of all this nagging
# < i m tired of all this nagging
# Correct
#
# > vous etes odieux
# = you re obnoxious
# < you re obnoxious
# Correct
#
# > elles sont toutes parties
# = they re all gone
# < they re all gone
# Correct
#
# > vous etes egoistes
# = you re selfish
# < you re selfish
# Correct
#
# > ils ont le meme age
# = they are the same age
# < they are the same age
# Correct
#
# > je vous invite
# = i m inviting you
# < i m inviting you you
# Incorrect
#
# > nous sommes pareils
# = we re the same
# < we re the same one
# Incorrect
#
# > je recherche un emploi monsieur
# = i am looking for a job sir
# < i am looking for a job sir
# Correct
#
# > ce sont tous deux des collegues a moi
# = they are both colleagues of mine
# < they are both colleagues of mine
# Correct
#
# > nous en sommes en partie responsables
# = we are in part responsible for it
# < we are in part responsible for it s
# Incorrect
#
# > je suis italien
# = i m italian
# < i am italian than italian
# Incorrect
#
# > tu es beau
# = you re beautiful
# < you re beautiful
# Correct
#
# > nous sommes piegees
# = we re trapped
# < we re trapped
# Correct
#
# > t es givree !
# = you re nuts !
# < you re nuts !
# Correct
#
# > vous etes fort raffine
# = you re very sophisticated
# < you re very sophisticated
# Correct
#
# > ce sont des eleves
# = they re students
# < they re students
# Correct
#
# > ils l adorent
# = they re very fond of him
# < they re very fond of him
# Correct
#
# > elle a peur de retomber malade
# = she is afraid of falling ill again
# < she is afraid of falling ill again
# Correct
#
# > il va avoir un choc
# = he s in for a shock
# < i m going to have a boyfriend
# Incorrect
#
# > tu es tres perspicace
# = you re very perceptive
# < you re very perceptive
# Correct
#
# > tu es pleine de ressources
# = you re resourceful
# < you re resourceful
# Correct
#
# > vous etes timide n est ce pas ?
# = you re shy aren t you ?
# < you re shy aren t you ?
# Correct
#
# > nous sommes toute ouie
# = we re all ears
# < we re all ears
# Correct
#
# > nous sommes enfin seuls
# = we re finally alone
# < we re finally alone alone
# Incorrect
#
# > vous etes trop lents
# = you re too slow
# < you re too slow
# Correct
#
# > je vais te donner une chance supplementaire
# = i m going to give you one more chance
# < i m going to give you one more chance
# Correct
#
# > je ne suis pas si pressee
# = i m not in that much of a hurry
# < i m not in that much of a hurry
# Correct
#
# > pour moi c est la fin des haricots
# = i m at the end of my rope
# < i m at the end of my rope
# Correct
#
# > je ne suis pas incroyant
# = i m not a disbeliever
# < i m not a disbeliever
# Correct
#
# > tu as raison bien sur
# = you re right of course
# < you re right of course
# Correct
#
# > vous etes influent
# = you re influential
# < you re influential
# Correct
#
# > vous devez faire comme je vous dis
# = you are to do as i tell you
# < you are to do as i tell you
# Correct
#
# > je suis fier d etre docteur
# = i am proud of being a doctor
# < i am proud of being a doctor
# Correct
#
# > il n est pas a la maison
# = he s not home
# < he s not home
# Correct
#
# > je ne suis pas vegetarien
# = i m not a vegetarian
# < i m not a vegetarian
# Correct
#
# > j en ai fini avec tout ca
# = i m done with all that
# < i m done with all that
# Correct
#
# > je suis certain de trouver un moyen
# = i m sure i will find a way
# < i m sure i will find a way
# Correct
#
# > elle n est pas assez bonne pour lui
# = she isn t good enough for him
# < she isn t good enough for him
# Correct
#
# > je suis a boston
# = i m in boston
# < i m boston at boston
# Incorrect
#
# > il est bon pour resoudre des problemes mathematiques complexes
# = he is good at solving complicated mathematical problems
# < he is good at solving complicated mathematical problems
# Correct
#
# > j en suis contente
# = i m happy with that
# < i m happy with that
# Correct
#
# > je suis desole de vous avoir fait attendre
# = i m sorry to have kept you waiting
# < i am sorry to have kept you waiting
# Incorrect
#
# > son travail l absorbe
# = he is absorbed in his work
# < he is absorbed in his work
# Correct
#
# > je ne suis pas convaincu
# = i m not convinced
# < i m not persuaded
# Incorrect
#
# > je tombe
# = i m falling
# < i m falling things
# Incorrect
#
# > vous etes tres raffine
# = you re very sophisticated
# < you re very sophisticated
# Correct
#
# > il va se joindre a notre cercle
# = he s going to join our club
# < he s going to join our club
# Correct
#
# > vous etes tres effronte
# = you re very forward
# < you re very forward
# Correct
#
# > c est moi la patronne
# = i m the boss
# < i m the boss s me
# Incorrect
#
# > vous etes un petit menteur
# = you re a little liar
# < you re a little liar
# Correct
#
# > elle a peur de la nuit
# = she s afraid of the dark
# < she s afraid of what we life
# Incorrect
#
# > je suis un peu fatigue
# = i m a little tired
# < i m a little bit tired
# Incorrect
#
# > il est follement epris d elle
# = he s crazy about her
# < he s crazy about her
# Correct
#
# > je ne suis pas heureuse
# = i am not happy
# < i m not happy
# Incorrect
#
# > elle est en danger
# = she is currently in danger
# < she is currently in danger
# Correct
#
# > je ne fais pas partie de leurs admirateurs
# = i m not a fan
# < i m not a fan
# Correct
#
# > je meurs de soif
# = i m dying of thirst
# < i m very thirsty
# Incorrect
#
# > je ne suis pas occupe
# = i m not busy
# < i m not busy busy
# Incorrect
#
# > vous etes endormis
# = you re sleepy
# < you re sleepy
# Correct
#
# > je suis encore ici
# = i m still here
# < i m still here yet
# Incorrect
#
# > je suis bon en maths
# = i am good at math
# < i am good at math
# Correct
#
# > je suis a court d idees
# = i m running out of ideas
# < i m running out of ideas
# Correct
#
# > je suis en train de cuire du pain
# = i am baking bread
# < i am baking bread
# Correct
#
# > nous ne sommes pas surs
# = we re not sure
# < we re not sure
# Correct
#
# > je suis impressionnee
# = i m impressed
# < i m impressed impressed
# Incorrect
#
# > vous etes fort astucieuse
# = you re very astute
# < you re very astute
# Correct
#
# > je ne suis pas d humeur a sortir
# = i m not in a mood to go out
# ...
# Correct
#
# > je ne cours pas le moindre danger
# = i m not in any danger
# < i m not in any danger in danger
# Incorrect
#
# > je ne suis qu un pauvre etudiant
# = i m just a poor student
# < i m just a poor student
# Correct
#
# > il va avoir un choc
# = he s in for a shock
# < i m going to have a boyfriend
# Incorrect
#
# > il est connu en tant que chanteur de rock
# = he is known as a rock singer
# < he is known as a rock singer
# Correct
#
# > j ai une dette envers toi
# = i m indebted to you
# < i m indebted to you for
# Incorrect
#
# > je suis a court de munitions
# = i m out of ammo
# < i m out of ammo
# Correct
#
# > je suis scolarisee a la maison
# = i m homeschooled
# < i m homeschooled
# Correct
#
# > il est devant la porte
# = he is in front of the door
# < he is in front of the door
# Correct
#
# > tu es celui qui m a forme
# = you re the one who trained me
# < you re the one who trained me
# Correct
#
# > je suis etudiant
# = i am a student
# < i am a student
# Correct
#
# > je vais me marier
# = i m going to get married
# < i m going to get married
# Correct
#
# > je vais maintenant y aller
# = i m going to go now
# < i m going to go now
# Correct
#
# > je suis age de vingt cinq ans
# = i m years old
# < i m years old
# Correct
#
# > je ne vais pas porter ca
# = i m not wearing this
# < i m not wearing this
# Correct
#
# > tu es invite
# = you re invited
# < you re invited
# Correct
#
# > je cherche une chambre a louer
# = i m looking for a room for rent
# < i m looking for a room for rent
# Correct
#
# > je dis seulement la verite
# = i m only telling the truth
# < i m only telling the truth
# Correct
#
# > vous etes tous prets
# = you re all set
# < you re all set
# Correct
#
# > tu es tres intelligent
# = you re very intelligent
# < you re very smart
# Incorrect
#
# > elle est dans une bonne passe
# = she s on a roll
# < she s on a roll
# Correct
#
# > elles sont en train de temporiser
# = they re stalling
# < they re stalling
# Correct
#
# > il est critique plutot que romancier
# = he is a critic rather than a novelist
# < he is a critic rather than a novelist
# Correct
#
# > je n en suis pas si sur !
# = i m not so sure
# < i m not so sure
# Correct
#
# > je commence a avoir sommeil
# = i m getting sleepy
# < i m getting sleepy sleepy
# Incorrect
#
# > je suis applique
# = i m hardworking
# < i m hardworking
# Correct
#
# > ils sont tous morts
# = they are all dead
# < they re all dead dead
# Incorrect
#
# > je suis preoccupe
# = i m concerned
# < i m concerned
# Correct
#
# > je suis chanceuse de vous avoir comme amie
# = i m lucky to have you as a friend
# < i m lucky to have you as a friend
# Correct
#
# > vous allez perdre
# = you re going to lose
# < you re going to lose any pain
# Incorrect
#
# > nous sommes ici
# = we are here
# < we re here here
# Incorrect
#
# > tu as raison je pense
# = you re right i think
# < you re right i think i think
# Incorrect
#
# > je suis enfant unique
# = i am an only child
# < i am an only child
# Correct
#
# > vous n etes plus la bienvenue ici
# = you are no longer welcome here
# < you are no longer welcome here
# Correct
#
# > il plaisante toujours
# = he is always joking
# < i m still always looking for you
# Incorrect
#
# > il est detective
# = he is a detective
# < he is a detective
# Correct
#
# > je suis content de vous revoir
# = i m glad to see you again
# < i m glad to see you again
# Correct
#
# > vous etes tres droles
# = you re very funny
# < you re very funny aren
# Incorrect
#
# > je suis toujours prudent
# = i m always careful
# < i m always careful
# Correct
#
# > tu es distraite
# = you re forgetful
# < you re forgetful
# Correct
#
# > je suis content que ca te rende heureux
# = i m glad that makes you happy
# < i m glad that makes you happy
# Correct
#
# > je suis depourvue d idees
# = i m all out of ideas
# < i m all out of ideas
# Correct
#
# > elle a peur des chats
# = she is afraid of cats
# < she is afraid of cats
# Correct
#
# > ils font des affaires pas correctes
# = they re up to no good
# < they re up to no good
# Correct
#
# > nous devenons plus intimes
# = we re getting closer
# < we re getting closer
# Correct
#
# > pas question que je te laisse y aller
# = i m not letting you go
# < i m not letting you go
# Correct
#
# > c est mon professeur
# = he is my teacher
# < he is my teacher
# Correct
#
# > je suis chez une amie
# = i m at a friend s house
# < i m at a friend s house now
# Incorrect
#
# > nous sommes dans le meme bateau
# = we re in the same boat
# < we re in the same boat
# Correct
#
# > je n ai pas sommeil
# = i m not sleepy
# < i m not sleepy sleepy
# Incorrect
#
# > il a peur de me parler
# = he s scared to talk to me
# < i m afraid i can at everything
# Incorrect
#
# > nous sommes tous les memes
# = we re all the same
# < we re all the same size
# Incorrect
#
# > je lis une lettre
# = i am reading a letter
# < i am reading a letter
# Correct
#
# > j y vais
# = i m going
# < i m going to get work
# Incorrect
#
# > je ne suis pas si veinard
# = i m not so lucky
# < i m not so lucky right
# Incorrect
#
# > je me deshabille
# = i am undressing
# < i m getting undressed
# Incorrect
#
# > je suis hongrois
# = i am hungarian
# < i am hungarian
# Correct
#
# > il est parti pour affaires
# = he s away on business
# < he s away on business
# Correct
#
# > je suis heureux avec ce que je possede
# = i m happy with what i ve got
# < i m happy with what i ve got
# Correct
#
# > je suis en train de parler
# = i m speaking
# < i m talking
# Incorrect
#
# > vous etes tres brave
# = you re very brave
# < you re very brave
# Correct
#
# > tu es suffisant
# = you re conceited
# < you re conceited
# Correct
#
# > tu es imprudent
# = you re foolish
# < you re foolish
# Correct
#
# > tu reagis de maniere excessive
# = you re overreacting
# < you re overreacting
# Correct
#
# > je vais me cacher quelque part pres d ici
# = i m going to hide somewhere near here
# < i m going to hide somewhere near here
# Correct
#
# > je quitte la ville pour quelques jours
# = i am leaving town for a few days
# < i am leaving town for a few days
# Correct
#
# > tu es plus mignonne que mary
# = you re cuter than mary
# < you re cuter than mary
# Correct
#
# > il fait profession d avocat
# = he is a lawyer by profession
# < he is a lawyer by profession
# Correct
#
# > je suis capable de faire mes propres choix
# = i m capable of making my own decisions
# < i m capable of making my own decisions
# Correct
#
# > c est un homme honnete
# = he is an honest man
# < he is an honest man by poor
# Incorrect
#
# > il est nerveux et facilement effraye
# = he s nervous and easily frightened
# < he s nervous and gets scared easily frightened
# Incorrect
#
# > il ment comme un arracheur de dents
# = he is lying through his teeth
# < he is lying through his teeth
# Correct
#
# > je vais a l hopital
# = i m going to the hospital
# < i m going to the hospital to go
# Incorrect
#
# > c est un ecologiste
# = he is an environmentalist
# < he is an environmentalist
# Correct
#
# > moi aussi je suis un debutant
# = i m a beginner too
# < i m a beginner too
# Correct
#
# > tu es tres ingenieuse
# = you re very clever
# < you re very clever clever
# Incorrect
#
# > je suis tres petit
# = i m very short
# < i m very short of money
# Incorrect
#
# > elles sont en train de temporiser
# = they re stalling
# < they re stalling
# Correct
#
# > je suis aussi choquee que toi
# = i m as shocked as you are
# < i m as shocked as you are
# Correct
#
# > vous vous plaignez toujours
# = you are always complaining
# < you re always complaining about you
# Incorrect
#
# > c est un tres bon musicien
# = he s a very fine musician
# < he s a very fine musician
# Correct
#
# > nous avons toutes faim
# = we re all hungry
# < we re all hungry hungry
# Incorrect
#
# > je commence vraiment a m inquieter
# = i m really starting to get worried
# < i m really starting to get worried
# Correct
#
# > elles sont medecins
# = they re doctors
# < they re doctors
# Correct
#
# > tu es sur la bonne pente
# = you re on the right track
# < you re on the right track
# Correct
#
# > elles vivent dans un monde de fantaisie
# = they re living in a fantasy world
# < they re living in a fantasy world
# Correct
#
# > on est enfin seules
# = we re finally alone
# < i m sorry alone alone
# Incorrect
#
# > je suis etourdi
# = i m forgetful
# < i m forgetful
# Correct
#
# > nous avons fini de parler
# = we re done talking
# < we re done talking to talk
# Incorrect
#
# > je veux faire mes excuses
# = i m willing to apologize
# < i m willing to apologize
# Correct
#
# > je ne vais nulle part avec ma voiture
# = i m not driving anywhere
# < i m not driving anywhere
# Correct
#
# > il a a peu pres mon age
# = he is about my age
# < he is about my age
# Correct
#
# > c est un joueur de tennis
# = he is a tennis player
# < he is a tennis player
# Correct
#
# > je suis etranger ici
# = i am a stranger here
# < i am a stranger here
# Correct
#
# > nous craignons de manquer notre train
# = we re afraid we ll miss our train
# < we re afraid we ll miss our train
# Correct
#
# > vous etes branche
# = you re fashionable
# < you re fashionable
# Correct
#
# > je suis ton chef
# = i m your boss
# < i m your boss to me
# Incorrect
#
# > je suis desole mon pere est sorti
# = i m sorry my father is out
# < i m sorry my father is out
# Correct
#
# > il ne s y rend pas
# = he s not going
# < he s not going to be no friend
# Incorrect
#
# > je suis degoute
# = i m disgusted
# < i m disgusted !
# Incorrect
#
# > je suis optimiste
# = i m optimistic
# < i m optimistic
# Correct
#
# > je cherche un portefeuille
# = i m looking for a wallet
# < i m looking for a wallet i a long
# Incorrect
#
# > c est deja un homme
# = he s already a man
# < he s already a man now
# Incorrect
#
# > tout le monde parle de lui en bien
# = he is well spoken of by everybody
# < he is well spoken of by everybody
# Correct
#
# > ce sont des chretiens
# = they are christians
# < they are christians
# Correct
#
# > je suis choquee
# = i m shocked
# < i m shocked
# Correct
#
# > je suis satisfaite de leur representation
# = i m pleased with their performance
# < i m pleased with their performance
# Correct
#
# > je suis un homme d affaires respectable
# = i m a respectable businessman
# < i m a respectable businessman
# Correct
#
# > il travaille dans la recherche sur le sida
# = he is working in aids research
# < he is working in aids research
# Correct
#
# > il est handicape mental
# = he is mentally handicapped
# < he is mentally handicapped
# Correct
#
# > je ne suis pas interesse par ton opinion
# = i m not interested in your opinion
# < i m not interested in your opinion
# Correct
#
# > je maigris
# = i m losing weight
# < i m losing weight
# Correct
#
# > je suis en conge aujourd hui
# = i am off today
# < i am off today
# Correct
#
# > vous etes tres contrariee
# = you re very upset
# < you re very upset
# Correct
#
# > il est prompt a exprimer ses inquietudes
# = he is quick to voice his concerns
# < he is quick to voice his concerns
# Correct
#
# > je suis desole je ne parle pas francais
# = i m sorry i don t speak french
# < i m sorry i don t speak french
# Correct
#
# > tu es trop lent
# = you re too slow
# < you re too slow to understand
# Incorrect
#
# > il cuisine a la demande
# = he s a short order cook
# < he s a short order cook for you
# Incorrect
#
# > je m y habitue
# = i m getting used to it
# < i m getting used to it
# Correct
#
# > tu es plus grande que moi
# = you are taller than me
# < you re taller than me
# Incorrect
#
# > il a trois ans de plus que moi
# = he s three years older than me
# < he s three years older than me
# Correct
#
# > je ne suis pas vieux
# = i m not old
# < i m not old enough
# Incorrect
#
# > il a peur de nager
# = he is afraid of swimming
# < i m afraid i can t swim
# Incorrect
#
# > vous etes dingues !
# = you re nuts !
# < you re nuts !
# Correct
#
# > je ne suis pas comme les autres gens
# = i m not like other people
# < i m not like other people
# Correct
#
# > elle s en sort tres bien
# = she s getting on all right
# < she s getting on all right
# Correct
#
# > je ne suis pas matinal
# = i am not a morning person
# < i am not a morning person
# Correct
#
# > vous etes fort sages
# = you re very wise
# < you re very wise
# Correct
#
# > elles sont similaires
# = they re similar
# < they re similar
# Correct
#
# > tu es fort bonne
# = you re very good
# < you re very good at it
# Incorrect
#
# > je ne vais pas te dire mon nom
# = i m not going to tell you my name
# < i m not going to tell you my name
# Correct
#
# > j apprends a conduire
# = i m learning how to drive
# < i m learning how to drive drive
# Incorrect
#
# > je suis desole je ne parle pas le francais
# = i m sorry i don t speak french
# < i m sorry i don t speak french
# Correct
#
# > elles sont tres compatibles
# = they are very compatible
# < they are very compatible as
# Incorrect
#
# > je suis en bonne sante
# = i m in good health
# < i m in good health
# Correct
#
# > il fait profession d avocat
# = he is a lawyer by profession
# < he is a lawyer by profession
# Correct
#
# > j en ai marre de vos plaintes
# = i m getting tired of your complaints
# < i m getting tired of your complaints
# Correct
#
# > je suis impartial
# = i m unbiased
# < i m unbiased
# Correct
#
# > je suis desole je suis occupe pour l instant
# = i m sorry i m busy right now
# < i m sorry i m busy right now
# Correct
#
# > il est dans la lune
# = he is distracted
# < he is distracted
# Correct
#
# > vous etes fort comprehensif
# = you re very understanding
# < you re very understanding
# Correct
#
# > il est toujours plein d idees
# = he is always full of ideas
# < he is always full of ideas
# Correct
#
# > c est un cardiologue
# = he s a cardiologist
# < he s a cardiologist liar
# Incorrect
#
# > tu fais la bonne chose
# = you re doing the right thing
# < you re doing the right thing
# Correct
#
# > je ne vous laisse pas seuls tous les deux
# = i m not leaving the two of you alone
# < i m not leaving the two of you alone
# Correct
#
# > tu es celui la
# = you are the one
# < you re the one one who trained me
# Incorrect
#
# > je vais regarder la tele
# = i m going to watch tv
# < i m going to watch tv all the
# Incorrect
#
# > nous y sommes
# = we are here
# < we re in charge
# Incorrect
#
# > je suis veinard
# = i m in luck
# < i m one of you
# Incorrect
#
# > je suis tres fier de mon fils
# = i m very proud of my son
# < i m very proud of my son
# Correct
#
# > tu es trop faible
# = you re too weak
# < you re too weak by weak
# Incorrect
#
# > vous n etes pas rationnelles
# = you re not being rational
# < you re not being manipulated
# Incorrect
#
# > il est raisonnable dans ses exigences
# = he is reasonable in his demands
# < he is reasonable in his demands
# Correct
#
# > nous sommes enfin seules
# = we re finally alone
# < we re finally alone
# Correct
#
# > je suis heureux de vous voir
# = i m glad to see you
# < i m glad to see you
# Correct
#
# > nous ne faisons que commencer
# = we re just starting
# < we re just beginning to do
# Incorrect
#
# > tu n es pas comme les autres
# = you aren t like the others
# < you aren t like the others
# Correct
#
# > tu es fort courageuse
# = you re very brave
# < you re very brave
# Correct
#
# > nous sommes un peu occupes ici
# = we re a little busy here
# < we re a little busy here
# Correct
#
# > elle va apprendre a conduire
# = she is going to learn how to drive
# < she is going to learn how to drive
# Correct
#
# > je ne suis pas en train de mourir
# = i m not dying
# < i m not dying
# Correct
#
# > elle saute a la corde
# = she is skipping rope
# < she is skipping rope
# Correct
#
# > il a besoin d argent
# = he is in need of money
# < he is in need of money
# Correct
#
# > c est vous l enseignant
# = you re the teacher
# < you re the teacher
# Correct
#
# > c est une pietre cuisiniere
# = she is a poor cook
# < she is a poor cook
# Correct
#
# > tu es merveilleuse
# = you re wonderful
# < you re wonderful stupid
# Incorrect
#
# > je ne suis pas idiot
# = i m not a fool
# < i m not a fool
# Correct
#
# > je manque de pratique
# = i m out of practice
# < i m out of practice
# Correct
#
# > j apprends vite
# = i m a fast learner
# < i m a quick learner
# Incorrect
#
# > nous sommes tout sauf prets pour le rude hiver
# = we are all but ready for the cold winter
# < we are all but ready for the cold winter
# Correct
#
# > je suis en service
# = i m on duty
# < i am on duty on duty
# Incorrect
#
# > elle passe a la tele ce soir
# = she is appearing on tv tonight
# < she is appearing on tv tonight
# Correct
#
# > on le dit decede
# = he is said to have died
# < he is said to have died just be
# Incorrect
#
# > vous n etes pas un saint
# = you re no saint
# < you re no saint
# Correct
#
# > nous sommes a egalite
# = we are even
# < we are even friends
# Incorrect
#
# > c est une tres gentille fille
# = she s a very nice girl
# < she s a very nice girl
# Correct
#
# > tu es le professeur
# = you re the teacher
# < you re the teacher s teacher
# Incorrect
#
# > il est devant nous en mathematiques
# = he is ahead of us in mathematics
# < he is ahead of us in mathematics
# Correct
#
# > il a environ votre age
# = he s about the same age as you are
# < he s about the same age as you are
# Correct
#
# > je n en suis pas fiere
# = i m not proud of it
# < i m not proud of that
# Incorrect
#
# > j ai la baraka
# = i m very fortunate
# < i m very fortunate
# Correct
#
# Accuracy: 71.65% (1433/2000)

# %% [markdown]
# Visualizing Attention
# =====================
#
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# You could simply run `plt.matshow(attentions)` to see attention output
# displayed as a matrix. For a better viewing experience we will do the
# extra work of adding axes and labels:

# %%
def showAttention(input_sentence, output_words, attentions):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.cpu().numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    # plt.show()
    plt.savefig(f'{input_sentence}attention_plot.png')  # Save the plot as a file
    plt.close()  # Close the plot


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(encoder, decoder, input_sentence, input_lang, output_lang)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions[0, :len(output_words), :])


evaluateAndShowAttention('il n est pas aussi grand que son pere')

evaluateAndShowAttention('je suis trop fatigue pour conduire')

evaluateAndShowAttention('je suis desole si c est une question idiote')

evaluateAndShowAttention('je suis reellement fiere de vous')
# Out:
# input = il n est pas aussi grand que son pere
# output = he is not as tall as his father <EOS>
# C:\Users\shami\AppData\Local\Temp\ipykernel_10496\595099033.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + input_sentence.split(' ') +
# C:\Users\shami\AppData\Local\Temp\ipykernel_10496\595099033.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([''] + output_words)
# input = je suis trop fatigue pour conduire
# output = i m too tired to drive <EOS>
# input = je suis desole si c est une question idiote
# output = i m sorry if this is a stupid question <EOS>
# input = je suis reellement fiere de vous
# output = i m really proud of you <EOS>

# %% [markdown]
# Exercises
# =========
#
# -   Try with a different dataset
#     -   Another language pair
#     -   Human → Machine (e.g. IOT commands)
#     -   Chat → Response
#     -   Question → Answer
# -   Replace the embeddings with pretrained word embeddings such as
#     `word2vec` or `GloVe`
# -   Try with more layers, more hidden units, and more sentences. Compare
#     the training time and results.
# -   If you use a translation file where pairs have two of the same
#     phrase (`I am test \t I am test`), you can use this as an
#     autoencoder. Try this:
#     -   Train as an autoencoder
#     -   Save only the Encoder network
#     -   Train a new Decoder for translation from there
